# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishlavasa/LGMVIP--DataScience/blob/main/Beginner_Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Let's Grow More (LGMVIP) - "DATA SCIENCE INTERN"**
# ###<center>**LGMVIP July-22**
# **AUTHOR - KRISH GOYAL**
# ####*Beginner Level Task*

# %% [markdown]
# ### **TASK-3- Image to Pencil Sketch with Python:**
# *We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.*

# %% [markdown]
# ### **Importing Modules**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Read the image**

# %%
image=cv2.imread("Scenary.jpg")
RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
plt.show()

# %% [markdown]
# ### **Step 1: Convert to Grey Image**

# %%
gray_image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)
plt.axis(False)
plt.show()

# %% [markdown]
# ### **Step 2: Invert ImageStep**

# %%
inverted_image=cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)
plt.axis(False)
plt.show()

# %% [markdown]
# ### **Step 3: Blur image**

# %%
blured_image=cv2.GaussianBlur(inverted_image, (21,21),0)
plt.imshow(blured_image)
plt.axis(False)
plt.show()

# %% [markdown]
# ### **Step 4: Invert Blurred Image**

# %%
invblur_image=cv2.bitwise_not(blured_image)
plt.imshow(invblur_image)
plt.axis(False)
plt.show()

# %% [markdown]
# ### **Step 5: Sketch**

# %%
sketch_image = cv2.divide(gray_image,invblur_image, scale=256.0)
plt.imshow(sketch_image)
plt.axis(False)
plt.show()

cv2.imwrite('sketch.png', sketch_image)
# Out:
# True

# %% [markdown]
# ### **Step 6: Display sketch**

# %%
rgb_sketch=cv2.cvtColor(sketch_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Original Image vs Sketch**

# %%
# ORIGINAL IMAGE
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original Image', size=30)
plt.imshow(RGB_img)
plt.axis('off')

# SKETCH IMAGE
plt.subplot(1,2,2)
plt.title('Sketch', size=30)
rgb_sketch=cv2.cvtColor(sketch_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()

# %% [markdown]
# ### **Conclusion: RBG format image converted into grayscale image**
